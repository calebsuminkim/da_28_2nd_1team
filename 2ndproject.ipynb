# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5).T
# Out:
#                                                                     20290  \
# id                                                                2326252
# log_price                                                        3.912023
# property_type                                                       House
# room_type                                                    Private room
# amenities               {TV,"Wireless Internet","Air conditioning",Kit...
# accommodates                                                            1
# bathrooms                                                             2.0
# bed_type                                                         Real Bed
# cancellation_policy                                              flexible
# cleaning_fee                                                         True
# city                                                                   LA
# description             Our beautiful home has 6 bedrooms plus 4 bathr...
# ...

# %%
df.columns.unique()
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
df.corrwith(df['log_price']).sort_values(ascending = True)
# Out:
# longitude              -0.047529
# number_of_reviews      -0.032470
# id                     -0.007178
# latitude               -0.002193
# review_scores_rating    0.091219
# cleaning_fee            0.111191
# bathrooms               0.355420
# beds                    0.442153
# bedrooms                0.473212
# accommodates            0.567574
# log_price               1.000000
# dtype: float64

# %%
plt.figure(figsize = (20, 12))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df['review_scores_rating'].isnull().sum()
# Out:
# 16722

# %%
df['review_scores_rating'].

# %%
sns.boxplot(x=df['review_scores_rating'])
# Out:
# <AxesSubplot:xlabel='review_scores_rating'>

# %%
sns.boxplot(x=df['number_of_reviews'])
# Out:
# <AxesSubplot:xlabel='number_of_reviews'>

# %%
df.hist(bins = 50, figsize = (20, 15))
plt.show()

# %%
pd.plotting.scatter_matrix(df.columns, figsize=(12, 8), alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5128\198054322.py in <module>
# ----> 1 pd.plotting.scatter_matrix(df.columns, figsize=(12, 8), alpha=0.3)
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     142     """
#     143     plot_backend = _get_plot_backend("matplotlib")
# --> 144     return plot_backend.scatter_matrix(
#     145         frame=frame,
#     146         alpha=alpha,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      45     **kwds,
#      46 ):
# ---> 47     df = frame._get_numeric_data()
#      48     n = df.columns.size
# ...

# %%
len(df['number_of_reviews'])
# Out:
# 74111

# %% [markdown]
# ### 필요없는 열 삭제

# %%
air = df[['city', 'property_type', 'room_type', 'amenities', 'accommodates', 'bathrooms', 'cleaning_fee', 'host_identity_verified', 'instant_bookable', 'latitude', 'longitude', 'bedrooms', 'beds']]
air.head(5).T
# Out:
#                                                                         0  \
# city                                                                  NYC
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            3
# bathrooms                                                             1.0
# cleaning_fee                                                         True
# host_identity_verified                                                  t
# instant_bookable                                                        f
# latitude                                                        40.696524
# longitude                                                      -73.991617
# bedrooms                                                              1.0
# ...

# %%
len(air['amenities']), len(air['amenities'].unique())
# Out:
# (74111, 67122)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5128\40852002.py in <module>
# ----> 1 air['amenities_count'] = list(map(lambda x:len(x.split(',')), df.loc[amenities]))
#
# NameError: name 'amenities' is not defined

# %%
for i in air['amenites']:
    print(len(air['amenities'].unique()[23].split(',')))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'amenites'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
air['host_identity_verified'].isnull().sum()
# Out:
# 188

# %%
df[['longitude', 'latitude']]
# Out:
#         longitude   latitude
# 0      -73.991617  40.696524
# 1      -73.989040  40.766115
# 2      -73.943756  40.808110
# 3     -122.431619  37.772004
# 4      -77.034596  38.925627
# ...           ...        ...
# 74106  -73.939405  40.709025
# 74107 -118.396053  33.871549
# 74108  -73.942377  40.706749
# 74109  -74.000157  40.738535
# 74110 -118.192409  33.761096
#
# [74111 rows x 2 columns]

# %%
df.plot(kind = 'scatter', x = 'longitude', y = 'latitude', alpha = 0.1, grid = True)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
# !pip install folium
# Out:
# ...
#      -------------------------------------- 102.3/102.3 kB 5.8 MB/s eta 0:00:00
# ...

# %%
import folium
from folium import plugins

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5128\4017947959.py in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'
